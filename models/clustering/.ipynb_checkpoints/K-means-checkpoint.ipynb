# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering, SpectralClustering
from scipy.cluster.hierarchy import dendrogram
from sklearn.metrics import silhouette_score, homogeneity_score

from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv("/home/ivana/Desktop/IP-projekat/2023_Data_Mining_Smoking_Dataset/datasets/data1.csv")
data.columns
# Out:
# Index(['Unnamed: 0', 'gender', 'age', 'height(cm)', 'weight(kg)', 'waist(cm)',
#        'eyesight(left)', 'eyesight(right)', 'hearing(left)', 'hearing(right)',
#        'systolic', 'relaxation', 'fasting blood sugar', 'Cholesterol',
#        'triglyceride', 'HDL', 'LDL', 'hemoglobin', 'Urine protein',
#        'serum creatinine', 'AST', 'ALT', 'Gtp', 'dental caries', 'tartar',
#        'smoking'],
#       dtype='object')

# %%
data.drop('Unnamed: 0', axis=1,inplace=True)
data.columns
# Out:
# Index(['gender', 'age', 'height(cm)', 'weight(kg)', 'waist(cm)',
#        'eyesight(left)', 'eyesight(right)', 'hearing(left)', 'hearing(right)',
#        'systolic', 'relaxation', 'fasting blood sugar', 'Cholesterol',
#        'triglyceride', 'HDL', 'LDL', 'hemoglobin', 'Urine protein',
#        'serum creatinine', 'AST', 'ALT', 'Gtp', 'dental caries', 'tartar',
#        'smoking'],
#       dtype='object')

# %%
Y = data['smoking']
X = data.drop('smoking', axis=1)
feature_names = X.columns
X.head()
# Out:
#    gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0       0   40         155          60       81.3             1.2
# 1       0   40         160          60       81.0             0.8
# 2       1   55         170          60       80.0             0.8
# 3       1   40         165          70       88.0             1.5
# 4       0   40         155          60       86.0             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...   HDL    LDL  \
# 0              1.0            1.0             1.0     114.0  ...  73.0  126.0
# 1              0.6            1.0             1.0     119.0  ...  42.0  127.0
# 2              0.8            1.0             1.0     138.0  ...  55.0  151.0
# 3              1.5            1.0             1.0     100.0  ...  45.0  226.0
# 4              1.0            1.0             1.0     120.0  ...  62.0  107.0
#
#    hemoglobin  Urine protein  serum creatinine   AST   ALT   Gtp  \
# 0        12.9            1.0               0.7  18.0  19.0  27.0
# 1        12.7            1.0               0.6  22.0  19.0  18.0
# 2        15.8            1.0               1.0  21.0  16.0  22.0
# 3        14.7            1.0               1.0  19.0  26.0  18.0
# 4        12.5            1.0               0.6  16.0  14.0  22.0
#
#    dental caries  tartar
# 0              0       1
# 1              0       1
# 2              0       0
# 3              0       1
# 4              0       0
#
# [5 rows x 24 columns]

# %%
scaler = MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=feature_names)
X
# Out:
#        gender       age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0         0.0  0.307692    0.416667    0.285714   0.388462        0.112245
# 1         0.0  0.307692    0.500000    0.285714   0.384615        0.071429
# 2         1.0  0.538462    0.666667    0.285714   0.371795        0.071429
# 3         1.0  0.307692    0.583333    0.380952   0.474359        0.142857
# 4         0.0  0.307692    0.416667    0.285714   0.448718        0.091837
# ...       ...       ...         ...         ...        ...             ...
# 55687     0.0  0.307692    0.666667    0.333333   0.307692        0.081633
# 55688     0.0  0.384615    0.500000    0.190476   0.243590        0.112245
# 55689     0.0  0.538462    0.500000    0.190476   0.224359        0.091837
# 55690     1.0  0.615385    0.583333    0.285714   0.346154        0.071429
# 55691     1.0  0.538462    0.500000    0.333333   0.435897        0.081633
#
#        eyesight(right)  hearing(left)  hearing(right)  systolic  ...  \
# 0             0.091837            0.0             0.0  0.254438  ...
# 1             0.051020            0.0             0.0  0.284024  ...
# 2             0.071429            0.0             0.0  0.396450  ...
# 3             0.142857            0.0             0.0  0.171598  ...
# 4             0.091837            0.0             0.0  0.289941  ...
# ...                ...            ...             ...       ...  ...
# 55687         0.081633            0.0             0.0  0.230769  ...
# 55688         0.112245            0.0             0.0  0.177515  ...
# 55689         0.112245            0.0             0.0  0.272189  ...
# 55690         0.091837            0.0             0.0  0.366864  ...
# 55691         0.061224            0.0             0.0  0.313609  ...
#
#             HDL       LDL  hemoglobin  Urine protein  serum creatinine  \
# 0      0.112378  0.067240    0.493827            0.0          0.052174
# 1      0.061889  0.067778    0.481481            0.0          0.043478
# 2      0.083062  0.080689    0.672840            0.0          0.078261
# 3      0.066775  0.121033    0.604938            0.0          0.078261
# 4      0.094463  0.057020    0.469136            0.0          0.043478
# ...         ...       ...         ...            ...               ...
# 55687  0.115635  0.062937    0.456790            0.0          0.043478
# 55688  0.112378  0.041958    0.561728            0.0          0.069565
# 55689  0.122150  0.033351    0.462963            0.0          0.034783
# 55690  0.071661  0.077999    0.586420            0.0          0.052174
# 55691  0.048860  0.080151    0.623457            0.0          0.060870
#
#             AST       ALT       Gtp  dental caries  tartar
# 0      0.009195  0.006179  0.026052            0.0     1.0
# 1      0.012261  0.006179  0.017034            0.0     1.0
# 2      0.011494  0.005149  0.021042            0.0     0.0
# 3      0.009962  0.008582  0.017034            0.0     1.0
# 4      0.007663  0.004463  0.021042            0.0     0.0
# ...         ...       ...       ...            ...     ...
# 55687  0.006130  0.002060  0.009018            1.0     1.0
# 55688  0.010728  0.003776  0.013026            0.0     1.0
# 55689  0.008429  0.003433  0.011022            0.0     0.0
# 55690  0.010728  0.006179  0.017034            0.0     0.0
# 55691  0.015326  0.009612  0.040080            0.0     1.0
#
# [55692 rows x 24 columns]

# %%
pca = PCA(n_components=2)
X = pca.fit_transform(X)

# %%
pca.explained_variance_ratio_[:2].sum()
# Out:
# 0.6258300085473719

# %%
_ = plt.scatter(X[:, 0], X[:, 1], c=Y)

# %% [raw]
# cluster_range = range(1, 10)
# sse = []
# for num_clusters in cluster_range:
#
#     kmeans = KMeans(n_clusters=num_clusters, random_state=0)
#     kmeans.fit(X)
#
#     sse.append(kmeans.inertia_)
#
# # Plot the elbow curve
# plt.plot(cluster_range, sse, marker='o')
# plt.xlabel('Number of Clusters')
# plt.ylabel('Sum of Squared Distances')
# plt.title('Elbow Method')
# plt.show()

# %%
ks = [i for i in range(2, 10)]
sse = []
silhouettes = []

fig, axs = plt.subplots(4, 2, figsize=(12, 20))
fig.suptitle("KMeans")

for k, ax in zip(ks, axs.flatten()):
    kmeans = KMeans(n_clusters=k, n_init=10)
    kmeans.fit(X)

    ax.scatter(X[:, 0], X[:, 1], c=kmeans.labels_)
    ax.set_title(f"clusters={k}")
    ax.set_xlabel("Principal Component 1")
    ax.set_ylabel("Principal Component 2")

    sse.append(kmeans.inertia_)
    silhouettes.append(silhouette_score(X, kmeans.labels_))

plt.tight_layout()
plt.show()

# %%
sse
# Out:
# [14729.538291365103,
#  6179.618623380394,
#  1311.0578944976,
#  761.8816372992798,
#  515.9965738345225,
#  288.2257958266279,
#  169.6343623966926,
#  138.11289683072695]

# %%
silhouettes
# Out:
# [0.5484747812373977,
#  0.6970517932944904,
#  0.8324210199330784,
#  0.8305581052629489,
#  0.8273406935551455,
#  0.8306049701211137,
#  0.8298486884530553,
#  0.7696744494618774]

# %%
plt.plot(ks, silhouettes)

# %%
plt.plot(ks, sse)
plt.xticks(ks)
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
# Out:
# Text(0, 0.5, 'SSE')

# %%
km = KMeans(n_clusters=4, n_init=100, max_iter=500, init='random')
km.fit(X)
# Out:
# KMeans(init='random', max_iter=500, n_clusters=4, n_init=100)

# %%
plt.scatter(X[:, 0], X[:, 1], c=km.labels_)

# %%
# Silueta
silhouette_score(X, km.labels_, metric='euclidean')
# Out:
# 0.8324210199330784

# %%
# Homogenost klastera
homogeneity_score(labels_true=Y, labels_pred=km.labels_)
# Out:
# 0.2434588824635009

# %%
# koja instanca pripada kom klasteru
X[km.labels_ == 0]
# Out:
# array([[-0.46709654,  0.04772949],
#        [-0.54874177, -0.01910676],
#        [-0.76114536,  0.23106998],
#        ...,
#        [-0.48155636,  0.03257252],
#        [-0.50453865,  0.01380256],
#        [-0.42356329,  0.07432371]])

# %%
from sklearn.metrics import silhouette_samples

silhouette_values = silhouette_samples(X, kmeans.labels_)
silhouette_values
# Out:
# array([0.88646252, 0.85561568, 0.60086343, ..., 0.89436697, 0.65517492,
#        0.78412408])
